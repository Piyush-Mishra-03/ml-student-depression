# %% [markdown]
# # 🎓 Student Depression Dataset - Complete Overview
#
# Welcome to the analysis of the **Student Depression Dataset**, designed to uncover insights about student mental health based on lifestyle, academic stress, work pressure, and more.
#
# ---
#
# ## 📌 Objective
#
# - 🎯 Identify the **key factors** contributing to depression in students.
# - 🔍 Perform **EDA (Exploratory Data Analysis)** and build **ML models** to predict depression.
# - 💡 Support **early intervention** and **mental health awareness**.
#
# ---
#
# ## 🧠 Why This Dataset Matters
#
# > Mental health among students is an increasing concern globally. By analyzing data related to academics, sleep, satisfaction, and stress, we can help detect early signs of depression and recommend preventive actions.
#
# ---
#
# ## 📄 Dataset Source
#
# 🔗 **Kaggle Link**: [Click here to view the dataset](https://www.kaggle.com/code/sonawanelalitsunil/student-depression-data-ml-83-64/input)
#
# ---
#
# ## 🧾 Feature Descriptions
#
# | 🏷️ Feature Name                          | 🔍 Description |
# |------------------------------------------|----------------|
# | `id`                                     | Unique student identifier |
# | `Gender`                                 | Gender of the student (Male, Female, Other) |
# | `Age`                                    | Age of the student |
# | `City`                                   | Student's location |
# | `Profession`                             | Field of study or work |
# | `Academic Pressure`                      | Stress from academic workload |
# | `Work Pressure`                          | Stress due to job or internships |
# | `CGPA`                                   | Academic performance indicator |
# | `Study Satisfaction`                     | How satisfied the student is with their studies |
# | `Job Satisfaction`                       | Satisfaction with work (if working) |
# | `Sleep Duration`                         | Average sleep in hours per day |
# | `Dietary Habits`                         | Quality of nutrition and eating patterns |
# | `Degree`                                 | Degree/program currently pursued |
# | `Have you ever had suicidal thoughts ?`  | Whether the student had suicidal thoughts (Yes/No) |
# | `Work/Study Hours`                       | Daily hours spent on study/work |
# | `Financial Stress`                       | Stress due to money issues |
# | `Family History of Mental Illness`       | Any mental illness in the family (Yes/No) |
# | `Depression`                             | 🔴 **Target Variable** – Indicates if student is depressed (Yes/No) |
#
# ---
#
# ## 💬 Notes
#
# - The dataset contains **sensitive information**, so ethical handling is crucial.
# - This analysis can help educational institutions and counselors **design better support systems**.
#
# ---
#
# > 🧘‍♀️ *“Mental health is just as important as physical health. Let’s use data to make a difference.”*

# %% [markdown]
# ## ✨Loading and Previewing the Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset
depression_main = pd.read_csv('/content/student_depression_dataset-final.csv')
depression = depression_main.copy()
depression
# Out:
#              id  Gender   Age           City parental_support Profession  \
# 0           2.0    Male  33.0  Visakhapatnam              NaN    Student
# 1           8.0  Female  24.0      Bangalore              NaN    Student
# 2          26.0    Male  31.0            NaN              NaN    Student
# 3          30.0  Female  28.0       Varanasi              NaN    Student
# 4          32.0  Female  25.0         Jaipur              Yes    Student
# ...         ...     ...   ...            ...              ...        ...
# 27896  140685.0  Female  27.0          Surat              Yes    Student
# 27897  140686.0    Male  27.0       Ludhiana              NaN    Student
# 27898  140689.0    Male  31.0      Faridabad              NaN    Student
# 27899  140690.0  Female  18.0       Ludhiana              NaN    Student
# 27900  140699.0    Male  27.0          Patna              NaN    Student
#
#        Academic Pressure  Work Pressure  CGPA internet_availability  ...  \
# ...

# %%
depression.head()
# Out:
#      id  Gender   Age           City parental_support Profession  \
# 0   2.0    Male  33.0  Visakhapatnam              NaN    Student
# 1   8.0  Female  24.0      Bangalore              NaN    Student
# 2  26.0    Male  31.0            NaN              NaN    Student
# 3  30.0  Female  28.0       Varanasi              NaN    Student
# 4  32.0  Female  25.0         Jaipur              Yes    Student
#
#    Academic Pressure  Work Pressure  CGPA internet_availability  ...   Degree  \
# 0                5.0            0.0  8.97                   NaN  ...  B.Pharm
# 1                2.0            0.0  5.90             Available  ...      BSc
# 2                3.0            0.0  7.03             Available  ...       BA
# 3                3.0            0.0  5.59                   NaN  ...      BCA
# 4                4.0            0.0  8.13                   NaN  ...   M.Tech
#
#    Have you ever had suicidal thoughts ? physical_health Work/Study Hours  \
# ...

# %%
depression.tail()
# Out:
#              id  Gender   Age       City parental_support Profession  \
# 27896  140685.0  Female  27.0      Surat              Yes    Student
# 27897  140686.0    Male  27.0   Ludhiana              NaN    Student
# 27898  140689.0    Male  31.0  Faridabad              NaN    Student
# 27899  140690.0  Female  18.0   Ludhiana              NaN    Student
# 27900  140699.0    Male  27.0      Patna              NaN    Student
#
#        Academic Pressure  Work Pressure  CGPA internet_availability  ...  \
# 27896                5.0            0.0  5.75             Available  ...
# 27897                2.0            0.0  9.40                   NaN  ...
# 27898                3.0            0.0  6.61                   NaN  ...
# 27899                5.0            0.0  6.88             Available  ...
# 27900                4.0            0.0  9.24                   NaN  ...
#
#            Degree  Have you ever had suicidal thoughts ? physical_health  \
# ...

# %%
depression.dtypes
# Out:
# id                                       float64
# Gender                                    object
# Age                                      float64
# City                                      object
# parental_support                          object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# internet_availability                     object
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# social_activities                         object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# physical_health                           object
# Work/Study Hours                         float64
# ...

# %%
depression.shape
# Out:
# (27901, 25)

# %%
depression.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27899 non-null  float64
#  1   Gender                                 27882 non-null  object
#  2   Age                                    27853 non-null  float64
#  3   City                                   27845 non-null  object
#  4   parental_support                       9724 non-null   object
#  5   Profession                             27882 non-null  object
#  6   Academic Pressure                      27870 non-null  float64
#  7   Work Pressure                          27878 non-null  float64
#  8   CGPA                                   27883 non-null  float64
#  9   internet_availability                  6974 non-null   object
# ...

# %%
depression.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'parental_support', 'Profession',
#        'Academic Pressure', 'Work Pressure', 'CGPA', 'internet_availability',
#        'Study Satisfaction', 'Job Satisfaction', 'Sleep Duration',
#        'social_activities', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'physical_health',
#        'Work/Study Hours', 'FiNaNcial Stress',
#        'Family History of Mental Illness', 'Depression', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
depression.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27899.000000  27853.000000       27870.000000    27878.00000
# mean    70437.239543     25.825046           3.141263        0.00043
# std     40638.494245      4.905668           1.381340        0.04401
# min         2.000000     18.000000           0.000000        0.00000
# 25%     35036.500000     21.000000           2.000000        0.00000
# 50%     70662.000000     26.000000           3.000000        0.00000
# 75%    105812.000000     30.000000           4.000000        0.00000
# max    140699.000000     59.000000           5.000000        5.00000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27883.000000        27883.000000      27891.000000      27877.000000
# mean       7.655835            2.943873          0.000681          7.157585
# std        1.470643            1.361115          0.044402          3.707276
# ...

# %% [markdown]
# ## ✨Data Info & Nulls Check

# %%
null_values = depression.isnull().sum()
null_values
# Out:
# id                                           2
# Gender                                      19
# Age                                         48
# City                                        56
# parental_support                         18177
# Profession                                  19
# Academic Pressure                           31
# Work Pressure                               23
# CGPA                                        18
# internet_availability                    20927
# Study Satisfaction                          18
# Job Satisfaction                            10
# Sleep Duration                              21
# social_activities                         8471
# Dietary Habits                              21
# Degree                                      21
# Have you ever had suicidal thoughts ?       33
# physical_health                           4197
# Work/Study Hours                            24
# FiNaNcial Stress                            24
# ...

# %%
highest_null_values = null_values[null_values > 9000]
print(highest_null_values)
# Out:
# parental_support         18177
# internet_availability    20927
# Unnamed: 22              27901
# Unnamed: 23              27901
# Unnamed: 24              27901
# dtype: int64

# %%
depression.drop(['parental_support','internet_availability','physical_health','social_activities','Unnamed: 24','Unnamed: 23','Unnamed: 22'],axis=1,inplace=True)

# %%
depression.isnull().sum()
# Out:
# id                                        2
# Gender                                   19
# Age                                      48
# City                                     56
# Profession                               19
# Academic Pressure                        31
# Work Pressure                            23
# CGPA                                     18
# Study Satisfaction                       18
# Job Satisfaction                         10
# Sleep Duration                           21
# Dietary Habits                           21
# Degree                                   21
# Have you ever had suicidal thoughts ?    33
# Work/Study Hours                         24
# FiNaNcial Stress                         24
# Family History of Mental Illness         22
# Depression                               19
# dtype: int64

# %%
depression.dropna(inplace=True)

# %%
depression.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# FiNaNcial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
depression.duplicated().sum()
# Out:
# np.int64(0)

# %%
depression.sample()
# Out:
#            id  Gender   Age   City Profession  Academic Pressure  \
# 3194  16091.0  Female  30.0  Surat    Student                5.0
#
#       Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3194            0.0  9.93                 1.0               0.0
#
#      Sleep Duration Dietary Habits Degree  \
# 3194    '5-6 hours'      Unhealthy    BBA
#
#      Have you ever had suicidal thoughts ?  Work/Study Hours FiNaNcial Stress  \
# 3194                                    No               9.0                2
#
#      Family History of Mental Illness  Depression
# 3194                               No         1.0

# %%
depression['Depression'].unique()
# Out:
# array([1., 0.])

# %%
depression.groupby('Degree')['Depression'].sum()
# Out:
# Degree
# 'Class 12'    4256.0
# B.Arch         864.0
# B.Com          844.0
# B.Ed          1004.0
# B.Pharm        424.0
# B.Tech         651.0
# BA             319.0
# BBA            402.0
# BCA            810.0
# BE             332.0
# BHM            503.0
# BSc            517.0
# LLB            352.0
# LLM            259.0
# M.Com          386.0
# M.Ed           410.0
# M.Pharm        310.0
# M.Tech         519.0
# MA             288.0
# MBA            301.0
# MBBS           399.0
# MCA            556.0
# MD             295.0
# ME              97.0
# MHM             98.0
# MSc            673.0
# Others          21.0
# PhD            285.0
# Name: Depression, dtype: float64

# %%
depression.groupby('Profession')['Depression'].sum()
# Out:
# Profession
# 'Civil Engineer'                1.0
# 'Content Writer'                2.0
# 'Digital Marketer'              2.0
# 'Educational Consultant'        1.0
# 'UX/UI Designer'                1.0
# Architect                       7.0
# Chef                            2.0
# Doctor                          2.0
# Entrepreneur                    1.0
# Lawyer                          1.0
# Manager                         1.0
# Pharmacist                      2.0
# Student                     16147.0
# Teacher                         5.0
# Name: Depression, dtype: float64

# %%
depression.groupby('Profession')['Depression'].sum().sort_values(ascending=False)
# Out:
# Profession
# Student                     16147.0
# Architect                       7.0
# Teacher                         5.0
# Chef                            2.0
# 'Digital Marketer'              2.0
# 'Content Writer'                2.0
# Pharmacist                      2.0
# Doctor                          2.0
# 'Civil Engineer'                1.0
# 'Educational Consultant'        1.0
# 'UX/UI Designer'                1.0
# Entrepreneur                    1.0
# Lawyer                          1.0
# Manager                         1.0
# Name: Depression, dtype: float64

# %%
depression.groupby('Gender')['Depression'].sum()
# Out:
# Gender
# Female    7147.0
# Male      9028.0
# Name: Depression, dtype: float64

# %%
# First, clean the text values
depression['Sleep Duration'] = depression['Sleep Duration'].str.strip().str.replace("'", '')

# Create the mapping
sleep_map = {
    'Less than 5 hours': 4,
    '5-6 hours': 5.5,
    '7-8 hours': 7.5,
    'More than 8 hours': 9
}

# Map the cleaned text to numeric values
depression['Sleep_Hours'] = depression['Sleep Duration'].map(sleep_map)

# %%
depression['Sleep_Hours'].sample(20)
# Out:
# 10581    7.5
# 12402    9.0
# 24000    5.5
# 7526     7.5
# 20003    5.5
# 8499     4.0
# 12978    4.0
# 14215    4.0
# 949      7.5
# 13416    7.5
# 2585     9.0
# 15263    4.0
# 1728     7.5
# 17424    9.0
# 27431    7.5
# 22087    9.0
# 9024     4.0
# 7902     4.0
# 1940     5.5
# 24085    5.5
# Name: Sleep_Hours, dtype: float64

# %%
depression['Sleep_Hours'].isnull().sum()
# Out:
# np.int64(18)

# %%
depression.fillna(depression['Sleep_Hours'].mean(),inplace=True)

# %%
depression.drop('Sleep Duration',axis=1,inplace=True)

# %%
depression.groupby('Sleep_Hours')['Depression'].sum()
# Out:
# Sleep_Hours
# 4.000000    5300.0
# 5.500000    3478.0
# 6.339712       9.0
# 7.500000    4335.0
# 9.000000    3053.0
# Name: Depression, dtype: float64

# %%
depression.groupby('Profession')['Sleep_Hours'].mean()
# Out:
# Profession
# 'Civil Engineer'            5.500000
# 'Content Writer'            6.500000
# 'Digital Marketer'          6.166667
# 'Educational Consultant'    7.500000
# 'UX/UI Designer'            7.500000
# Architect                   7.125000
# Chef                        7.500000
# Doctor                      4.000000
# Entrepreneur                4.000000
# Lawyer                      9.000000
# Manager                     9.000000
# Pharmacist                  8.250000
# Student                     6.339242
# Teacher                     6.500000
# Name: Sleep_Hours, dtype: float64

# %%
# Drop 'id' column if it exists
depression.drop(columns=['id'], inplace=True)

# %% [markdown]
# ## Data Visualisation

# %%
depression
# Out:
#        Gender   Age           City Profession  Academic Pressure  \
# 0        Male  33.0  Visakhapatnam    Student                5.0
# 1      Female  24.0      Bangalore    Student                2.0
# 3      Female  28.0       Varanasi    Student                3.0
# 4      Female  25.0         Jaipur    Student                4.0
# 11       Male  33.0       Vadodara    Student                3.0
# ...       ...   ...            ...        ...                ...
# 27896  Female  27.0          Surat    Student                5.0
# 27897    Male  27.0       Ludhiana    Student                2.0
# 27898    Male  31.0      Faridabad    Student                3.0
# 27899  Female  18.0       Ludhiana    Student                5.0
# 27900    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0                0.0  8.97                 2.0               0.0
# ...

# %%
sns.countplot(data=depression, x='Sleep_Hours',hue='Depression')
plt.title('Sleep Duration Distribution')
# Out:
# Text(0.5, 1.0, 'Sleep Duration Distribution')

# %%
sns.histplot(data=depression, x='Sleep_Hours', bins=6, kde=True)
plt.title('Distribution of Sleep Hours')
# Out:
# Text(0.5, 1.0, 'Distribution of Sleep Hours')

# %%
depression['Depression'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Proportion of Depression Levels')
# Out:
# Text(0.5, 1.0, 'Proportion of Depression Levels')

# %%
sns.boxplot(data=depression, x='Depression', y='Sleep_Hours')
plt.title('Sleep Hours by Depression Level')
# Out:
# Text(0.5, 1.0, 'Sleep Hours by Depression Level')

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(depression.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Between Numeric Features')
# Out:
# Text(0.5, 1.0, 'Correlation Between Numeric Features')

# %%
pd.crosstab(depression['Profession'], depression['Depression']).plot(kind='bar', stacked=True)
plt.title('Depression by Internet Usage')
# Out:
# Text(0.5, 1.0, 'Depression by Internet Usage')

# %%
# Sleep Duration vs. Depression (Scatter Plot)
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Sleep_Hours', y='Depression', hue='Gender', data=depression, alpha=0.7)
plt.title("Sleep Duration vs. Depression")
plt.xlabel("Sleep Duration (hours)")
plt.ylabel("Depression Level")
plt.show()

# %%
# Financial Stress vs. Depression (Violin Plot)
plt.figure(figsize=(6, 4))
sns.violinplot(x='FiNaNcial Stress', y='Depression', data=depression, palette='viridis')
plt.title("Financial Stress vs. Depression")
plt.show()
# Out:
# /tmp/ipython-input-2035658160.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='FiNaNcial Stress', y='Depression', data=depression, palette='viridis')

# %%
depression.dtypes
# Out:
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# FiNaNcial Stress                          object
# Family History of Mental Illness          object
# Depression                               float64
# Sleep_Hours                              float64
# dtype: object

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection  import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier

from sklearn.decomposition import PCA
print('Done')
# Out:
# Done

# %%
depression.rename(columns={
    'Have you ever had suicidal thoughts ?':'Suicidal_thoughts',
    'Family History of Mental Illness': 'Mental Illness'
    },inplace=True)

# %%
le = LabelEncoder()
depression['Mental Illness'] = le.fit_transform(depression['Mental Illness'])
depression['FiNaNcial Stress'] = le.fit_transform(depression['FiNaNcial Stress'])
depression['Suicidal_thoughts'] = le.fit_transform(depression['Suicidal_thoughts'])
depression['Degree'] = le.fit_transform(depression['Degree'])
depression['Dietary Habits'] = le.fit_transform(depression['Dietary Habits'])
depression['Profession'] = le.fit_transform(depression['Profession'])
depression['City'] = le.fit_transform(depression['City'])
depression['Gender'] = le.fit_transform(depression['Gender'])

depression.head(150)
# Out:
#      Gender   Age  City  Profession  Academic Pressure  Work Pressure  CGPA  \
# 0         1  33.0    51          12                5.0            0.0  8.97
# 1         0  24.0     5          12                2.0            0.0  5.90
# 3         0  28.0    49          12                3.0            0.0  5.59
# 4         0  25.0    18          12                4.0            0.0  8.13
# 11        1  33.0    48          12                3.0            0.0  7.03
# ..      ...   ...   ...         ...                ...            ...   ...
# 192       1  33.0    44          12                3.0            0.0  7.07
# 193       1  34.0    19          12                1.0            0.0  9.60
# 194       1  32.0     7          12                4.0            0.0  6.08
# 195       1  33.0    20          12                2.0            0.0  9.54
# 196       0  20.0    39          12                5.0            0.0  6.17
#
# ...

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(depression)
print(x_scaled)
# Out:
# [[ 0.89189336  1.4621878   1.53258994 ... -0.96893461  0.8407695
#   -0.43817413]
#  [-1.12121028 -0.37193921 -1.43355903 ...  1.03206139 -1.18938663
#   -0.43817413]
#  [-1.12121028  0.44322835  1.40362694 ...  1.03206139  0.8407695
#    0.60545515]
#  ...
#  [ 0.89189336  1.05460402 -1.04667003 ... -0.96893461 -1.18938663
#   -0.43817413]
#  [-1.12121028 -1.59469054 -0.14392904 ... -0.96893461  0.8407695
#   -1.2208961 ]
#  [ 0.89189336  0.23943646  0.69433045 ...  1.03206139  0.8407695
#   -1.2208961 ]]

# %%
x = depression.drop('Depression', axis=1)


y = depression['Depression']

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)
print(x_pca)
# Out:
# [[ 0.18907377 -0.10066945]
#  [-2.23844212 -0.0137313 ]
#  [ 0.90898847  0.1419974 ]
#  ...
#  [-1.6796687  -0.06163273]
#  [ 2.41825247  0.13855986]
#  [ 0.83957466 -0.06263385]]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_pca, y,test_size=0.3)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (19326, 2)
# (19326,)
# (8283, 2)
# (8283,)

# %%
x_train
# Out:
# array([[ 1.65325441,  0.0912767 ],
#        [ 1.15799735,  0.03160082],
#        [-2.55392829, -0.17781495],
#        ...,
#        [ 1.44949151, -0.06104403],
#        [-1.62171575, -0.10521255],
#        [-2.38848786, -0.06652629]])

# %%
y_train
# Out:
# 7948     1.0
# 15503    1.0
# 5369     0.0
# 510      1.0
# 26794    1.0
#         ...
# 3181     0.0
# 25742    0.0
# 11292    1.0
# 9278     0.0
# 14414    0.0
# Name: Depression, Length: 19326, dtype: float64

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [0. 1. 1. ... 1. 1. 1.]

# %%
print('Logistic Regression Accuracy:',accuracy_score(y_test,y_pred)*100)
# Out:
# Logistic Regression Accuracy: 95.32777978993118

# %%
rf = RandomForestClassifier(n_estimators=50)
rf.fit(x_train,y_train)
y_pred_rf = rf.predict(x_test)

print('Random Forest Accuracy:',accuracy_score(y_test,y_pred_rf)*100)
# Out:
# Random Forest Accuracy: 94.83279005191356

# %% [markdown]
# # 📝 Model Performance Summary
#
# The classification report below provides precision, recall, and F1-score for both classes.

# %%
print(f"✅ Accuracy: {accuracy_score(y_test, y_pred):.2%}")
print("\n📋 Classification Report:")
print(classification_report(y_test, y_pred, labels=[0, 1, 2]))
# Out:
# ✅ Accuracy: 95.33%
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      3346
#            1       0.96      0.96      0.96      4937
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.95      8283
#    macro avg       0.63      0.63      0.63      8283
# weighted avg       0.95      0.95      0.95      8283
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.savefig('Confusion.png')
plt.show()

# %%
# Convert target to numeric
y_numeric = pd.factorize(y)[0]

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(x_pca[:, 0], x_pca[:, 1], c=y_numeric, cmap='coolwarm', edgecolor='k', s=80)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA: 2D Projection of Heart Failure Data')
plt.colorbar(label='Target Classes')
plt.tight_layout()
plt.savefig('Confusion.png')
plt.show()

# %% [markdown]
# ## 📊 Comparing Model Accuracy
#
# This bar chart compares the accuracy of two machine learning models applied to the student depression dataset:
#
# - **Logistic Regression** achieved the highest accuracy at **95.40%**
# - **Random Forest** followed closely with **94.94%**
#
# Both models show strong performance in predicting depression, but Logistic Regression slightly edges out in this case.

# %%
# Model names and their corresponding accuracy scores
models = ['Logistic Regression', 'Random Forest']
accuracy = [95.40021731256792, 94.94144633586865]

# Creating the bar plot
plt.figure(figsize=(8, 5))
plt.bar(models, accuracy, color=['darkblue', 'darkgreen'])

# Adding labels and title
plt.xlabel('Models')
plt.ylabel('Accuracy (%)')
plt.title('Model Accuracy Comparison')
plt.ylim(70, 100)  # Setting y-axis limits for better visibility

# Display values on top of bars
for i, v in enumerate(accuracy):
    plt.text(i, v + 0.3, f"{v:.2f}%", ha='center', fontsize=10)

# Show the plot
plt.show()

# %% [markdown]
# # ✅ Final Thoughts
#
# The comparison above shows that both **Logistic Regression** and **Random Forest** models perform exceptionally well in predicting student depression, with Logistic Regression slightly outperforming at **95.40% accuracy**.
#
# ---
#
# ### 🎯 What We Achieved:
#
# - 🔍 Explored and understood key mental health factors among students
# - 📊 Visualized relationships using data analysis
# - 🧠 Trained multiple ML models to detect depression
# - 🏁 Identified the most accurate model (Logistic Regression)
#
# ---
#
# ### 📘 Key Insight:
#
# > *Even simple models like Logistic Regression can outperform complex ones when the data is clean and features are meaningful.*
#
# ---
#
# ### 🚀 Next Steps:
#
# - Test more models (e.g., SVM, XGBoost)
# - Apply cross-validation and fine-tuning
# - Share results with academic/mental health communities
#
# ---
#
# ---
#
# ### 🌟 Connect with Me
#
# - 📂 [GitHub Project Repo](https://github.com/Piyush-Mishra-03/ml-student-depression.git)
# - 💼 [LinkedIn](www.linkedin.com/in/piyush-mishra03)
#
# Let’s build for impact. 💚
#
# ---
#
#
# ### 🙌 Thank You!
#
# This notebook aimed to not just build a model, but to make a real-world impact using data. Let’s continue using AI responsibly to support mental health and well-being in education. 💚
